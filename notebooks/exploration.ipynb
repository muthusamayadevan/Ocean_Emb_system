# %% [markdown]
# # Exploration Notebook
#
# Use this notebook for quick data checks and exploring downloaded satellite and Argo float data.

# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt

print("Libraries imported successfully!")
